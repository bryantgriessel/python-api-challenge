# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 0        0  mawlamyinegyunn  16.3833   95.2667     78.93        86
# 1        1           kapa'a  22.0752 -159.3190     82.72        77
# 2        2            wuhai  39.6647  106.8122     79.59        19
# 3        3          xichang  27.8964  102.2634     67.06        88
# 4        4      west island -12.1568   96.8225     76.98        83
#
#    Cloudiness  Wind Speed Country      Date
# 0          38        4.54      MM  23/07/23
# 1         100       13.80      US  23/07/23
# 2           1        8.57      CN  23/07/23
# 3          99        1.14      CN  23/07/23
# 4          40       16.11      CC  23/07/23

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_data_map = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    color="City",
    size = "Humidity",
    scale = 1,
)
# Display the map
city_data_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
city_data_narrow= city_data_df[(city_data_df["Max Temp"] <90 )& (city_data_df["Humidity"]<70)&(city_data_df["Max Temp"] >70)]
# Drop any rows with null values
city_data_narrow.dropna()
# Display sample data
city_data_narrow
# Out:
#      City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 2          2               wuhai  39.6647  106.8122     79.59        19
# 8          8              bethel  41.3712  -73.4140     87.55        47
# 17        17  green cove springs  29.9919  -81.6781     79.45        68
# 21        21               tagta  41.6504   59.9164     80.55        41
# 35        35            hamilton  39.1834  -84.5333     87.80        48
# ..       ...                 ...      ...       ...       ...       ...
# 540      540             ajaccio  42.0000    8.9167     76.98        57
# 547      547        diego martin  10.7005  -61.5342     87.49        64
# 560      560                roma  43.2128  -75.4557     84.51        45
# 562      562           caiaponia -16.9567  -51.8103     85.60        21
# 566      566             jiuquan  39.7432   98.5174     77.49        20
#
#      Cloudiness  Wind Speed Country      Date
# 2             1        8.57      CN  23/07/23
# 8             0        5.75      US  23/07/23
# 17          100       11.36      US  23/07/23
# 21            0        4.61      TM  23/07/23
# 35           40        9.22      US  23/07/23
# ..          ...         ...     ...       ...
# 540           0        2.30      FR  23/07/23
# 547          97       12.71      TT  23/07/23
# 560           0       11.50      US  23/07/23
# 562           0        8.37      BR  23/07/23
# 566          61        3.20      CN  23/07/23
#
# [96 rows x 10 columns]

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_narrow[['City', 'Country', 'Lat','Lng','Humidity']].copy()
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"]=''
# Display sample data
hotel_df.head(10)
# Out:
#                       City Country      Lat       Lng  Humidity Hotel Name
# 2                    wuhai      CN  39.6647  106.8122        19
# 8                   bethel      US  41.3712  -73.4140        47
# 17      green cove springs      US  29.9919  -81.6781        68
# 21                   tagta      TM  41.6504   59.9164        41
# 35                hamilton      US  39.1834  -84.5333        48
# 44               saynshand      MN  44.8824  110.1163        36
# 46                 qulsary      KZ  46.9531   54.0198        26
# 48                    hami      CN  42.8000   93.4500        15
# 50  happy valley-goose bay      CA  53.3168  -60.3315        61
# 52               fortaleza      BR  -3.7227  -38.5247        65

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
param = {
    "categories":"accommodation.hotel",
    "apiKey":geoapify_key,
    "format":"json",
    "limit:":1
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat=row["Lat"]
    long=row["Lng"]
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    param["filter"] = f"circle:{long},{lat},{radius}"
    param["bias"] = f"proximity:{long},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    response = requests.get(base_url, params=param)

    
    # Convert the API response to JSON format
    name_address = response.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# wuhai - nearest hotel: Binhe International Hotel
# bethel - nearest hotel: Hampton Inn Danbury
# green cove springs - nearest hotel: No hotel found
# tagta - nearest hotel: No hotel found
# hamilton - nearest hotel: North Vista Manor
# saynshand - nearest hotel: No hotel found
# qulsary - nearest hotel: Камилла
# hami - nearest hotel: Хами
# happy valley-goose bay - nearest hotel: Hotel North Two
# fortaleza - nearest hotel: Hotel Catedral
# pont rouge - nearest hotel: No hotel found
# yaiza - nearest hotel: Casa de Hilario
# fort mcmurray - nearest hotel: Nomad Hotel and Suites
# albany - nearest hotel: No hotel found
# nipomo - nearest hotel: Hampton Inn & Suites
# totness - nearest hotel: No hotel found
# williams lake - nearest hotel: Coast Fraser Inn
# jamestown - nearest hotel: DoubleTree Jamestown
# badger - nearest hotel: Hotel North Pole
# fort wellington - nearest hotel: No hotel found
# lexington - nearest hotel: Extended Stay America
# cromwell - nearest hotel: SpringHill Suites Hartford Cromwell
# lloydminster - nearest hotel: Central Suite Hotel Knight's Inn
# kill devil hills - nearest hotel: Mariner Days Inn & Suites
# alofi - nearest hotel: Matavai Resort
# san rafael del sur - nearest hotel: Barceló Montelimar Beach
# bakanas - nearest hotel: Карой
# afua - nearest hotel: No hotel found
# smara - nearest hotel: Hôtel Amine فندق الأمين
# zhangye - nearest hotel: Zhangye Hotel 张掖饭店
# college - nearest hotel: BEST WESTERN PLUS Pioneer Park Inn
# arroyo - nearest hotel: El Jardín de la Abadía
# yulinshi - nearest hotel: 榆溪大酒店
# crucecita - nearest hotel: No hotel found
# vincennes - nearest hotel: Le Home
# moroto - nearest hotel: Shalosa Hotel
# el charco - nearest hotel: No hotel found
# la ronge - nearest hotel: La Ronge Hotel and Suites
# watertown - nearest hotel: Four Points by Sheraton Boston Newton
# florence - nearest hotel: Old bridge Apartment
# campo formoso - nearest hotel: Hotel Rio das Pedras
# perry - nearest hotel: Hampton Inn & Suites
# mazagao - nearest hotel: No hotel found
# shahrud - nearest hotel: خانه معلم شاهرود
# peace river - nearest hotel: New Ridge Inn
# melfort - nearest hotel: No hotel found
# aktau - nearest hotel: Гульдана
# saryozek - nearest hotel: No hotel found
# moussoro - nearest hotel: No hotel found
# nueva esperanza - nearest hotel: Hotel Diana's
# feodosiya - nearest hotel: Afrodita
# acarau - nearest hotel: No hotel found
# flin flon - nearest hotel: Copperbelt Hotel
# mashhad - nearest hotel: هتل تعاون
# valdepenas - nearest hotel: Hotel Restaurante Su Casa
# jijel - nearest hotel: Hôtel Louiza
# kiskunmajsa - nearest hotel: Csipkerózsa Parkhotel
# cegrane - nearest hotel: hotel
# koulikoro - nearest hotel: No hotel found
# paracuru - nearest hotel: Vento Brasil
# sokoto - nearest hotel: Pinnade hotel
# chibougamau - nearest hotel: No hotel found
# wellston - nearest hotel: No hotel found
# hanceville - nearest hotel: No hotel found
# araxa - nearest hotel: Morada do Sol
# port-saint-louis-du-rhone - nearest hotel: No hotel found
# yorkton - nearest hotel: Ramada Yorkton
# stony plain - nearest hotel: Stony Plain Hotel
# turkmenbasy - nearest hotel: Türkmenbaşy Oteli
# fada n'gourma - nearest hotel: Auberge Diana
# maloye ganyushkino - nearest hotel: Конил Сазы
# safi - nearest hotel: No hotel found
# argostolion - nearest hotel: Ainos Hotel
# dazkiri - nearest hotel: Ekiz Otel
# houghton - nearest hotel: Quality Inn & Suites
# new glasgow - nearest hotel: Travelodge Suites
# aparecida de goiania - nearest hotel: Vison Motel
# sao vicente - nearest hotel: Pousada Vitória
# cabimas - nearest hotel: No hotel found
# bitola - nearest hotel: Robevski lux
# guerrero negro - nearest hotel: Plaza sal paraiso
# gowurdak - nearest hotel: No hotel found
# camocim - nearest hotel: Hotel Camocim
# nahrin - nearest hotel: No hotel found
# taubate - nearest hotel: Pousada do Viajante
# yeed - nearest hotel: No hotel found
# puerto san jose - nearest hotel: Martita
# pisco - nearest hotel: La Portada
# jinchang - nearest hotel: No hotel found
# lincoln city - nearest hotel: Inn at Lincoln City
# portland - nearest hotel: the Hoxton
# ajaccio - nearest hotel: Hôtel Sole e Monte
# diego martin - nearest hotel: Chaconia Hotel
# roma - nearest hotel: Wingate by Wyndham Rome
# caiaponia - nearest hotel: No hotel found
# jiuquan - nearest hotel: 民族宾馆
#                    City Country      Lat       Lng  Humidity  \
# 2                 wuhai      CN  39.6647  106.8122        19
# 8                bethel      US  41.3712  -73.4140        47
# 17   green cove springs      US  29.9919  -81.6781        68
# 21                tagta      TM  41.6504   59.9164        41
# 35             hamilton      US  39.1834  -84.5333        48
# ..                  ...     ...      ...       ...       ...
# 540             ajaccio      FR  42.0000    8.9167        57
# 547        diego martin      TT  10.7005  -61.5342        64
# 560                roma      US  43.2128  -75.4557        45
# 562           caiaponia      BR -16.9567  -51.8103        21
# 566             jiuquan      CN  39.7432   98.5174        20
#
#                     Hotel Name
# 2    Binhe International Hotel
# 8          Hampton Inn Danbury
# 17              No hotel found
# 21              No hotel found
# 35           North Vista Manor
# ..                         ...
# 540         Hôtel Sole e Monte
# 547             Chaconia Hotel
# 560    Wingate by Wyndham Rome
# 562             No hotel found
# 566                       民族宾馆
#
# [96 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 0.5,
    color = "City",
    hover_cols = ["Hotel Name", "Country"]

)
# Display the map
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
