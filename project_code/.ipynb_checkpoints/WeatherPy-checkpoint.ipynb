# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 581

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url =  url+"appid="+weather_api_key+"&q="+city+"&units="+units
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    print (city_url)
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
            # Parse the JSON and retrieve data
        city_weather = requests.get(city_url)
        city_json = city_weather.json()
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        print(city_json['coord']['lat'])
        city_lat = city_json['coord']['lat']
        city_lng = city_json['coord']['lon']
        city_max_temp = city_json['main']['temp']
        city_humidity = city_json['main']['humidity']

        city_clouds = city_json['clouds']['all']
        city_wind = city_json['wind']['speed']
        city_country = city_json['sys']['country']
        dt = city_json['dt']

    # if you encounter a "year is out of range" error the timestamp
    # may be in milliseconds, try `ts /= 1000` in that case

        city_date=datetime.utcfromtimestamp(dt).strftime('%Y-%m-%d %H:%M:%S')
        city_date=city_date[:-8].strip()
        print(city_date)

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                           "Humidity": city_humidity,
                           "Cloudiness": city_clouds,
                           "Wind Speed": city_wind,
                           "Country": city_country,
                           "Date": city_date
                         })

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | invercargill
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=invercargill&units=imperial
# -46.4
# 2023-07-27
# Processing Record 2 of Set 1 | adamstown
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=adamstown&units=imperial
# -25.066
# 2023-07-27
# Processing Record 3 of Set 1 | setubal
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=setubal&units=imperial
# 38.5244
# 2023-07-27
# Processing Record 4 of Set 1 | mejit
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=mejit&units=imperial
# 10.2753
# 2023-07-27
# Processing Record 5 of Set 1 | beitbridge
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=beitbridge&units=imperial
# -22.2167
# 2023-07-27
# Processing Record 6 of Set 1 | puerto natales
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=puerto natales&units=imperial
# -51.7236
# 2023-07-27
# Processing Record 7 of Set 1 | bilibino
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=bilibino&units=imperial
# 68.0546
# 2023-07-27
# Processing Record 8 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=georgetown&units=imperial
# 5.4112
# 2023-07-27
# Processing Record 9 of Set 1 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=port lincoln&units=imperial
# -34.7333
# 2023-07-27
# Processing Record 10 of Set 1 | macapa
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=macapa&units=imperial
# 0.0389
# 2023-07-27
# Processing Record 11 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=ushuaia&units=imperial
# -54.8
# 2023-07-27
# Processing Record 12 of Set 1 | waitangi
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=waitangi&units=imperial
# -43.9535
# 2023-07-27
# Processing Record 13 of Set 1 | lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=lompoc&units=imperial
# 34.6391
# 2023-07-27
# Processing Record 14 of Set 1 | uturoa
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=uturoa&units=imperial
# -16.7333
# 2023-07-27
# Processing Record 15 of Set 1 | taiohae
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=taiohae&units=imperial
# City not found. Skipping...
# Processing Record 16 of Set 1 | saudarkrokur
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=saudarkrokur&units=imperial
# 65.7461
# 2023-07-27
# Processing Record 17 of Set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=thompson&units=imperial
# 55.7435
# 2023-07-27
# Processing Record 18 of Set 1 | kelibia
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=kelibia&units=imperial
# 36.8476
# 2023-07-27
# Processing Record 19 of Set 1 | khorostkiv
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=khorostkiv&units=imperial
# 49.2111
# 2023-07-27
# Processing Record 20 of Set 1 | sharm el-sheikh
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=sharm el-sheikh&units=imperial
# 27.8518
# 2023-07-27
# Processing Record 21 of Set 1 | port-aux-francais
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=port-aux-francais&units=imperial
# -49.35
# 2023-07-27
# Processing Record 22 of Set 1 | taunggyi
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=taunggyi&units=imperial
# 20.7833
# 2023-07-27
# Processing Record 23 of Set 1 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=longyearbyen&units=imperial
# 78.2186
# 2023-07-27
# Processing Record 24 of Set 1 | enewetak
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=enewetak&units=imperial
# 11.3474
# 2023-07-27
# Processing Record 25 of Set 1 | lihue
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=lihue&units=imperial
# 21.9789
# 2023-07-27
# Processing Record 26 of Set 1 | hammerfest
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=hammerfest&units=imperial
# 70.6634
# 2023-07-27
# Processing Record 27 of Set 1 | sines
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=sines&units=imperial
# 37.9562
# 2023-07-27
# Processing Record 28 of Set 1 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=coquimbo&units=imperial
# -29.9533
# 2023-07-27
# Processing Record 29 of Set 1 | kilindoni
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=kilindoni&units=imperial
# -7.9139
# 2023-07-27
# Processing Record 30 of Set 1 | lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=lorengau&units=imperial
# -2.0226
# 2023-07-27
# Processing Record 31 of Set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=ribeira grande&units=imperial
# 38.5167
# 2023-07-27
# Processing Record 32 of Set 1 | vilyuchinsk
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=vilyuchinsk&units=imperial
# 52.9306
# 2023-07-27
# Processing Record 33 of Set 1 | nabire
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=nabire&units=imperial
# -3.3667
# 2023-07-27
# Processing Record 34 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=puerto ayora&units=imperial
# -0.7393
# 2023-07-27
# Processing Record 35 of Set 1 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=klaksvik&units=imperial
# 62.2266
# 2023-07-27
# Processing Record 36 of Set 1 | anadyr
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=anadyr&units=imperial
# 64.75
# 2023-07-27
# Processing Record 37 of Set 1 | urucui
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=urucui&units=imperial
# -7.2294
# 2023-07-27
# Processing Record 38 of Set 1 | cadale
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=cadale&units=imperial
# 2.7603
# 2023-07-27
# Processing Record 39 of Set 1 | papatowai
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=papatowai&units=imperial
# -46.5619
# 2023-07-27
# Processing Record 40 of Set 1 | mareeba
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=mareeba&units=imperial
# -17
# 2023-07-27
# Processing Record 41 of Set 1 | tolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=tolanaro&units=imperial
# -25.0319
# 2023-07-27
# Processing Record 42 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=punta arenas&units=imperial
# -53.15
# 2023-07-27
# Processing Record 43 of Set 1 | west island
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=west island&units=imperial
# -12.1568
# 2023-07-27
# Processing Record 44 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=bethel&units=imperial
# 41.3712
# 2023-07-27
# Processing Record 45 of Set 1 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=lebu&units=imperial
# -37.6167
# 2023-07-27
# Processing Record 46 of Set 1 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=lazaro cardenas&units=imperial
# 17.9583
# 2023-07-27
# Processing Record 47 of Set 1 | pishin
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=pishin&units=imperial
# 30.5803
# 2023-07-27
# Processing Record 48 of Set 1 | talakan
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=talakan&units=imperial
# 50.3167
# 2023-07-27
# Processing Record 49 of Set 1 | remire-montjoly
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=remire-montjoly&units=imperial
# 4.9167
# 2023-07-27
# Processing Record 50 of Set 1 | puerto lempira
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=puerto lempira&units=imperial
# 15.2667
# 2023-07-27
# Processing Record 0 of Set 2 | aljezur
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=aljezur&units=imperial
# 37.3191
# 2023-07-27
# Processing Record 1 of Set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=yellowknife&units=imperial
# 62.456
# 2023-07-27
# Processing Record 2 of Set 2 | howrah
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=howrah&units=imperial
# 22.5892
# 2023-07-27
# Processing Record 3 of Set 2 | edinburgh of the seven seas
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=edinburgh of the seven seas&units=imperial
# -37.0676
# 2023-07-27
# Processing Record 4 of Set 2 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=jamestown&units=imperial
# 42.097
# 2023-07-27
# Processing Record 5 of Set 2 | misratah
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=misratah&units=imperial
# 32.3754
# 2023-07-27
# Processing Record 6 of Set 2 | tura
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=tura&units=imperial
# 25.5198
# 2023-07-27
# Processing Record 7 of Set 2 | mawu
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=mawu&units=imperial
# 29.5923
# 2023-07-27
# Processing Record 8 of Set 2 | magadan
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=magadan&units=imperial
# 59.5667
# 2023-07-27
# Processing Record 9 of Set 2 | mumbwa
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=mumbwa&units=imperial
# -14.9783
# 2023-07-27
# Processing Record 10 of Set 2 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=mount gambier&units=imperial
# -37.8333
# 2023-07-27
# Processing Record 11 of Set 2 | wewak
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=wewak&units=imperial
# -3.5534
# 2023-07-27
# Processing Record 12 of Set 2 | pass christian
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=pass christian&units=imperial
# 30.3158
# 2023-07-27
# Processing Record 13 of Set 2 | shelton
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=shelton&units=imperial
# 41.3165
# 2023-07-27
# Processing Record 14 of Set 2 | kandira
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=kandira&units=imperial
# 41.0736
# 2023-07-27
# Processing Record 15 of Set 2 | vorgashor
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=vorgashor&units=imperial
# 67.5833
# 2023-07-27
# Processing Record 16 of Set 2 | itaituba
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=itaituba&units=imperial
# -4.2761
# 2023-07-27
# Processing Record 17 of Set 2 | fort st. john
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=fort st. john&units=imperial
# 56.2499
# 2023-07-27
# Processing Record 18 of Set 2 | fort bragg
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=fort bragg&units=imperial
# 35.139
# 2023-07-27
# Processing Record 19 of Set 2 | iskateley
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=iskateley&units=imperial
# 67.6803
# 2023-07-27
# Processing Record 20 of Set 2 | ouellah
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=ouellah&units=imperial
# City not found. Skipping...
# Processing Record 21 of Set 2 | port mathurin
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=port mathurin&units=imperial
# -19.6833
# 2023-07-27
# Processing Record 22 of Set 2 | olonkinbyen
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=olonkinbyen&units=imperial
# 70.9221
# 2023-07-27
# Processing Record 23 of Set 2 | utrik
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=utrik&units=imperial
# 11.2278
# 2023-07-27
# Processing Record 24 of Set 2 | hirara
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=hirara&units=imperial
# 24.8
# 2023-07-27
# Processing Record 25 of Set 2 | suva
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=suva&units=imperial
# -18.1416
# 2023-07-27
# Processing Record 26 of Set 2 | santa cruz
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=santa cruz&units=imperial
# -17.8
# 2023-07-27
# Processing Record 27 of Set 2 | monrovia
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=monrovia&units=imperial
# 6.3005
# 2023-07-27
# Processing Record 28 of Set 2 | blackmans bay
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=blackmans bay&units=imperial
# -43.0167
# 2023-07-27
# Processing Record 29 of Set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=bredasdorp&units=imperial
# -34.5322
# 2023-07-27
# Processing Record 30 of Set 2 | hawaiian paradise park
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=hawaiian paradise park&units=imperial
# 19.5933
# 2023-07-27
# Processing Record 31 of Set 2 | noyabrsk
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=noyabrsk&units=imperial
# 63.1994
# 2023-07-27
# Processing Record 32 of Set 2 | george town
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=george town&units=imperial
# 5.4112
# 2023-07-27
# Processing Record 33 of Set 2 | nuku'alofa
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=nuku'alofa&units=imperial
# -21.1333
# 2023-07-27
# Processing Record 34 of Set 2 | happy valley-goose bay
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=happy valley-goose bay&units=imperial
# 53.3168
# 2023-07-27
# Processing Record 35 of Set 2 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=ilulissat&units=imperial
# 69.2167
# 2023-07-27
# Processing Record 36 of Set 2 | forked river
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=forked river&units=imperial
# 39.8398
# 2023-07-27
# Processing Record 37 of Set 2 | krasnozerskoye
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=krasnozerskoye&units=imperial
# 53.9828
# 2023-07-27
# Processing Record 38 of Set 2 | lionel town
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=lionel town&units=imperial
# 17.8101
# 2023-07-27
# Processing Record 39 of Set 2 | atafu village
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=atafu village&units=imperial
# -8.5421
# 2023-07-27
# Processing Record 40 of Set 2 | ust-nera
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=ust-nera&units=imperial
# 64.5667
# 2023-07-27
# Processing Record 41 of Set 2 | guider
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=guider&units=imperial
# 9.9342
# 2023-07-27
# Processing Record 42 of Set 2 | stanley
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=stanley&units=imperial
# 54.868
# 2023-07-27
# Processing Record 43 of Set 2 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=kodiak&units=imperial
# 57.79
# 2023-07-27
# Processing Record 44 of Set 2 | badger
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=badger&units=imperial
# 64.8
# 2023-07-27
# Processing Record 45 of Set 2 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=avarua&units=imperial
# -21.2078
# 2023-07-27
# Processing Record 46 of Set 2 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=kloulklubed&units=imperial
# 7.0419
# 2023-07-27
# Processing Record 47 of Set 2 | sungailiat
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=sungailiat&units=imperial
# -1.85
# 2023-07-27
# Processing Record 48 of Set 2 | chonchi
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=chonchi&units=imperial
# -42.6128
# 2023-07-27
# Processing Record 49 of Set 2 | achinsk
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=achinsk&units=imperial
# 56.2694
# 2023-07-27
# Processing Record 0 of Set 3 | puerto baquerizo moreno
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=puerto baquerizo moreno&units=imperial
# -0.9
# 2023-07-27
# Processing Record 1 of Set 3 | zhangatas
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=zhangatas&units=imperial
# 43.5667
# 2023-07-27
# Processing Record 2 of Set 3 | grytviken
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=grytviken&units=imperial
# -54.2811
# 2023-07-27
# Processing Record 3 of Set 3 | huaraz
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=huaraz&units=imperial
# -9.5333
# 2023-07-27
# Processing Record 4 of Set 3 | lufilufi
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=lufilufi&units=imperial
# -13.8745
# 2023-07-27
# Processing Record 5 of Set 3 | aasiaat
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=aasiaat&units=imperial
# 68.7098
# 2023-07-27
# Processing Record 6 of Set 3 | gizo
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=gizo&units=imperial
# -8.103
# 2023-07-27
# Processing Record 7 of Set 3 | kodinsk
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=kodinsk&units=imperial
# 58.6881
# 2023-07-27
# Processing Record 8 of Set 3 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=cabo san lucas&units=imperial
# 22.8909
# 2023-07-27
# Processing Record 9 of Set 3 | qianjiang
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=qianjiang&units=imperial
# 30.4151
# 2023-07-27
# Processing Record 10 of Set 3 | st. john's
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=st. john's&units=imperial
# 47.5649
# 2023-07-27
# Processing Record 11 of Set 3 | corner brook
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=corner brook&units=imperial
# 48.9667
# 2023-07-27
# Processing Record 12 of Set 3 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=hithadhoo&units=imperial
# -0.6
# 2023-07-27
# Processing Record 13 of Set 3 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=iqaluit&units=imperial
# 63.7506
# 2023-07-27
# Processing Record 14 of Set 3 | walvis bay
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=walvis bay&units=imperial
# -22.9575
# 2023-07-27
# Processing Record 15 of Set 3 | leava
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=leava&units=imperial
# -14.3
# 2023-07-27
# Processing Record 16 of Set 3 | isafjordur
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=isafjordur&units=imperial
# 66.0755
# 2023-07-27
# Processing Record 17 of Set 3 | kidal
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=kidal&units=imperial
# 18.4411
# 2023-07-27
# Processing Record 18 of Set 3 | salekhard
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=salekhard&units=imperial
# 66.53
# 2023-07-27
# Processing Record 19 of Set 3 | fuyang
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=fuyang&units=imperial
# 32.9
# 2023-07-27
# Processing Record 20 of Set 3 | wailua homesteads
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=wailua homesteads&units=imperial
# 22.0669
# 2023-07-27
# Processing Record 21 of Set 3 | ola
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=ola&units=imperial
# 59.5833
# 2023-07-27
# Processing Record 22 of Set 3 | pointe-noire
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=pointe-noire&units=imperial
# -4.7761
# 2023-07-27
# Processing Record 23 of Set 3 | susuman
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=susuman&units=imperial
# 62.7833
# 2023-07-27
# Processing Record 24 of Set 3 | namibe
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=namibe&units=imperial
# -15.1961
# 2023-07-27
# Processing Record 25 of Set 3 | zarate
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=zarate&units=imperial
# -34.0981
# 2023-07-27
# Processing Record 26 of Set 3 | jeddah
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=jeddah&units=imperial
# 21.5169
# 2023-07-27
# Processing Record 27 of Set 3 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=mar del plata&units=imperial
# -38.0023
# 2023-07-27
# Processing Record 28 of Set 3 | igarka
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=igarka&units=imperial
# 67.4667
# 2023-07-27
# Processing Record 29 of Set 3 | aleksandrovsk-sakhalinskiy
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=aleksandrovsk-sakhalinskiy&units=imperial
# 50.8975
# 2023-07-27
# Processing Record 30 of Set 3 | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=luderitz&units=imperial
# -26.6481
# 2023-07-27
# Processing Record 31 of Set 3 | newman
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=newman&units=imperial
# 37.3138
# 2023-07-27
# Processing Record 32 of Set 3 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=saint-philippe&units=imperial
# -21.3585
# 2023-07-27
# Processing Record 33 of Set 3 | saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=saldanha&units=imperial
# -33.0117
# 2023-07-27
# Processing Record 34 of Set 3 | naze
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=naze&units=imperial
# 28.3667
# 2023-07-27
# Processing Record 35 of Set 3 | tara
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=tara&units=imperial
# 56.8944
# 2023-07-27
# Processing Record 36 of Set 3 | hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=hamilton&units=imperial
# 39.1834
# 2023-07-27
# Processing Record 37 of Set 3 | archidona
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=archidona&units=imperial
# 37.0965
# 2023-07-27
# Processing Record 38 of Set 3 | houlton
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=houlton&units=imperial
# 46.1262
# 2023-07-27
# Processing Record 39 of Set 3 | sinabang
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=sinabang&units=imperial
# 2.4803
# 2023-07-27
# Processing Record 40 of Set 3 | bac kan
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=bac kan&units=imperial
# 22.1333
# 2023-07-27
# Processing Record 41 of Set 3 | yokadouma
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=yokadouma&units=imperial
# 3.5167
# 2023-07-27
# Processing Record 42 of Set 3 | nemuro
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=nemuro&units=imperial
# 43.3236
# 2023-07-27
# Processing Record 43 of Set 3 | castillos
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=castillos&units=imperial
# -34.1667
# 2023-07-27
# Processing Record 44 of Set 3 | as sulayyil
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=as sulayyil&units=imperial
# 20.4607
# 2023-07-27
# Processing Record 45 of Set 3 | talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=talnakh&units=imperial
# 69.4865
# 2023-07-27
# Processing Record 46 of Set 3 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=saint-pierre&units=imperial
# -21.3393
# 2023-07-27
# Processing Record 47 of Set 3 | fuli
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=fuli&units=imperial
# 46.7217
# 2023-07-27
# Processing Record 48 of Set 3 | claremont
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=claremont&units=imperial
# 34.0967
# 2023-07-27
# Processing Record 49 of Set 3 | ha'il
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=ha'il&units=imperial
# 27.5219
# 2023-07-27
# Processing Record 0 of Set 4 | north ward
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=north ward&units=imperial
# -19.2454
# 2023-07-27
# Processing Record 1 of Set 4 | cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=cidreira&units=imperial
# -30.1811
# 2023-07-27
# Processing Record 2 of Set 4 | jinka
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=jinka&units=imperial
# 5.65
# 2023-07-27
# Processing Record 3 of Set 4 | ruayer
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=ruayer&units=imperial
# 43.0537
# 2023-07-27
# Processing Record 4 of Set 4 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=port alfred&units=imperial
# -33.5906
# 2023-07-27
# Processing Record 5 of Set 4 | portage la prairie
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=portage la prairie&units=imperial
# 49.9728
# 2023-07-27
# Processing Record 6 of Set 4 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=praia da vitoria&units=imperial
# 38.7333
# 2023-07-27
# Processing Record 7 of Set 4 | boguchany
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=boguchany&units=imperial
# 58.3814
# 2023-07-27
# Processing Record 8 of Set 4 | rampachodavaram
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=rampachodavaram&units=imperial
# 17.45
# 2023-07-27
# Processing Record 9 of Set 4 | olyokminsk
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=olyokminsk&units=imperial
# 60.3736
# 2023-07-27
# Processing Record 10 of Set 4 | swift current
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=swift current&units=imperial
# 50.2834
# 2023-07-27
# Processing Record 11 of Set 4 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=tiksi&units=imperial
# 71.6872
# 2023-07-27
# Processing Record 12 of Set 4 | temiskaming shores
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=temiskaming shores&units=imperial
# 47.4938
# 2023-07-27
# Processing Record 13 of Set 4 | kolasin
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=kolasin&units=imperial
# 42.8223
# 2023-07-27
# Processing Record 14 of Set 4 | tual
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=tual&units=imperial
# -5.6667
# 2023-07-27
# Processing Record 15 of Set 4 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=albany&units=imperial
# 42.6001
# 2023-07-27
# Processing Record 16 of Set 4 | grand falls-windsor
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=grand falls-windsor&units=imperial
# 48.9332
# 2023-07-27
# Processing Record 17 of Set 4 | rebola
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=rebola&units=imperial
# 3.7167
# 2023-07-27
# Processing Record 18 of Set 4 | petropavlovsk-kamchatsky
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=petropavlovsk-kamchatsky&units=imperial
# 53.0452
# 2023-07-27
# Processing Record 19 of Set 4 | barentu
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=barentu&units=imperial
# 15.1139
# 2023-07-27
# Processing Record 20 of Set 4 | sorong
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=sorong&units=imperial
# -0.8833
# 2023-07-27
# Processing Record 21 of Set 4 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=kalmunai&units=imperial
# 7.4167
# 2023-07-27
# Processing Record 22 of Set 4 | titao
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=titao&units=imperial
# 13.7667
# 2023-07-27
# Processing Record 23 of Set 4 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=arraial do cabo&units=imperial
# -22.9661
# 2023-07-27
# Processing Record 24 of Set 4 | kushiro
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=kushiro&units=imperial
# 42.975
# 2023-07-27
# Processing Record 25 of Set 4 | kolonia town
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=kolonia town&units=imperial
# 6.964
# 2023-07-27
# Processing Record 26 of Set 4 | hatton
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=hatton&units=imperial
# 6.8916
# 2023-07-27
# Processing Record 27 of Set 4 | broome
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=broome&units=imperial
# 42.2506
# 2023-07-27
# Processing Record 28 of Set 4 | alice springs
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=alice springs&units=imperial
# -23.7
# 2023-07-27
# Processing Record 29 of Set 4 | puerto armuelles
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=puerto armuelles&units=imperial
# 8.2833
# 2023-07-27
# Processing Record 30 of Set 4 | kurumkan
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=kurumkan&units=imperial
# 54.3
# 2023-07-27
# Processing Record 31 of Set 4 | madimba
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=madimba&units=imperial
# -10.4
# 2023-07-27
# Processing Record 32 of Set 4 | college
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=college&units=imperial
# 64.8569
# 2023-07-27
# Processing Record 33 of Set 4 | yamada
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=yamada&units=imperial
# 39.4667
# 2023-07-27
# Processing Record 34 of Set 4 | inari
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=inari&units=imperial
# 68.906
# 2023-07-27
# Processing Record 35 of Set 4 | puerto san carlos
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=puerto san carlos&units=imperial
# City not found. Skipping...
# Processing Record 36 of Set 4 | mgandu
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=mgandu&units=imperial
# -5.95
# 2023-07-27
# Processing Record 37 of Set 4 | ancud
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=ancud&units=imperial
# -41.8697
# 2023-07-27
# Processing Record 38 of Set 4 | kapuskasing
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=kapuskasing&units=imperial
# 49.4169
# 2023-07-27
# Processing Record 39 of Set 4 | poronaysk
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=poronaysk&units=imperial
# 49.2167
# 2023-07-27
# Processing Record 40 of Set 4 | bongouanou
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=bongouanou&units=imperial
# 6.6486
# 2023-07-27
# Processing Record 41 of Set 4 | constantia
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=constantia&units=imperial
# 44.1833
# 2023-07-27
# Processing Record 42 of Set 4 | baoying
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=baoying&units=imperial
# 33.2292
# 2023-07-27
# Processing Record 43 of Set 4 | smithers
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=smithers&units=imperial
# 54.7804
# 2023-07-27
# Processing Record 44 of Set 4 | tapes
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=tapes&units=imperial
# -30.6733
# 2023-07-27
# Processing Record 45 of Set 4 | fukuecho
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=fukuecho&units=imperial
# 32.6881
# 2023-07-27
# Processing Record 46 of Set 4 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=vila franca do campo&units=imperial
# 37.7167
# 2023-07-27
# Processing Record 47 of Set 4 | holualoa
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=holualoa&units=imperial
# 19.6228
# 2023-07-27
# Processing Record 48 of Set 4 | constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=constitucion&units=imperial
# -35.3333
# 2023-07-27
# Processing Record 49 of Set 4 | kataysk
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=kataysk&units=imperial
# 56.289
# 2023-07-27
# Processing Record 0 of Set 5 | bubaque
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=bubaque&units=imperial
# 11.2833
# 2023-07-27
# Processing Record 1 of Set 5 | san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=san patricio&units=imperial
# 28.017
# 2023-07-27
# Processing Record 2 of Set 5 | jatai
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=jatai&units=imperial
# -17.8814
# 2023-07-27
# Processing Record 3 of Set 5 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=port elizabeth&units=imperial
# -33.918
# 2023-07-27
# Processing Record 4 of Set 5 | murray bridge
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=murray bridge&units=imperial
# -35.1167
# 2023-07-27
# Processing Record 5 of Set 5 | timmins
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=timmins&units=imperial
# 48.4669
# 2023-07-27
# Processing Record 6 of Set 5 | colonia
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=colonia&units=imperial
# 50.9333
# 2023-07-27
# Processing Record 7 of Set 5 | klyuchi
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=klyuchi&units=imperial
# 52.2667
# 2023-07-27
# Processing Record 8 of Set 5 | ha tinh
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=ha tinh&units=imperial
# 18.3333
# 2023-07-27
# Processing Record 9 of Set 5 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=whitehorse&units=imperial
# 60.7161
# 2023-07-27
# Processing Record 10 of Set 5 | udachny
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=udachny&units=imperial
# 66.4167
# 2023-07-27
# Processing Record 11 of Set 5 | tralee
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=tralee&units=imperial
# 52.2704
# 2023-07-27
# Processing Record 12 of Set 5 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=carnarvon&units=imperial
# -24.8667
# 2023-07-27
# Processing Record 13 of Set 5 | tipasa
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=tipasa&units=imperial
# 36.5897
# 2023-07-27
# Processing Record 14 of Set 5 | labuan
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=labuan&units=imperial
# 5.2767
# 2023-07-27
# Processing Record 15 of Set 5 | tazovsky
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=tazovsky&units=imperial
# 67.4667
# 2023-07-27
# Processing Record 16 of Set 5 | antsiranana
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=antsiranana&units=imperial
# -12.2787
# 2023-07-27
# Processing Record 17 of Set 5 | barra de santo antonio
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=barra de santo antonio&units=imperial
# -9.4047
# 2023-07-27
# Processing Record 18 of Set 5 | polyarnyy
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=polyarnyy&units=imperial
# 69.1989
# 2023-07-27
# Processing Record 19 of Set 5 | codrington
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=codrington&units=imperial
# -38.2667
# 2023-07-27
# Processing Record 20 of Set 5 | sitka
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=sitka&units=imperial
# 57.0531
# 2023-07-27
# Processing Record 21 of Set 5 | 'ohonua
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q='ohonua&units=imperial
# City not found. Skipping...
# Processing Record 22 of Set 5 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=okhotsk&units=imperial
# 59.3833
# 2023-07-27
# Processing Record 23 of Set 5 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=sisimiut&units=imperial
# 66.9395
# 2023-07-27
# Processing Record 24 of Set 5 | uhrichsville
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=uhrichsville&units=imperial
# 40.3931
# 2023-07-27
# Processing Record 25 of Set 5 | byron bay
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=byron bay&units=imperial
# -28.65
# 2023-07-27
# Processing Record 26 of Set 5 | vokhtoga
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=vokhtoga&units=imperial
# 58.8147
# 2023-07-27
# Processing Record 27 of Set 5 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=nouadhibou&units=imperial
# 20.931
# 2023-07-27
# Processing Record 28 of Set 5 | manismata
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=manismata&units=imperial
# -2.4667
# 2023-07-27
# Processing Record 29 of Set 5 | dno
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=dno&units=imperial
# 57.8277
# 2023-07-27
# Processing Record 30 of Set 5 | tarquinia
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=tarquinia&units=imperial
# 42.2482
# 2023-07-27
# Processing Record 31 of Set 5 | dubinino
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=dubinino&units=imperial
# 55.6192
# 2023-07-27
# Processing Record 32 of Set 5 | kaeng khro
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=kaeng khro&units=imperial
# 16.1086
# 2023-07-27
# Processing Record 33 of Set 5 | bata
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=bata&units=imperial
# 1.8639
# 2023-07-27
# Processing Record 34 of Set 5 | laikit, laikit ii (dimembe)
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=laikit, laikit ii (dimembe)&units=imperial
# 1.4792
# 2023-07-27
# Processing Record 35 of Set 5 | det udom
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=det udom&units=imperial
# 14.906
# 2023-07-27
# Processing Record 36 of Set 5 | maues
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=maues&units=imperial
# -3.3836
# 2023-07-27
# Processing Record 37 of Set 5 | jiagedaqi
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=jiagedaqi&units=imperial
# 50.4167
# 2023-07-27
# Processing Record 38 of Set 5 | nova sintra
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=nova sintra&units=imperial
# 14.8667
# 2023-07-27
# Processing Record 39 of Set 5 | flin flon
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=flin flon&units=imperial
# 54.7682
# 2023-07-27
# Processing Record 40 of Set 5 | kimry
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=kimry&units=imperial
# 56.8667
# 2023-07-27
# Processing Record 41 of Set 5 | lembar
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=lembar&units=imperial
# City not found. Skipping...
# Processing Record 42 of Set 5 | lumberton
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=lumberton&units=imperial
# 34.6182
# 2023-07-27
# Processing Record 43 of Set 5 | alo
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=alo&units=imperial
# 7.4178
# 2023-07-27
# Processing Record 44 of Set 5 | chifeng
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=chifeng&units=imperial
# 42.2683
# 2023-07-27
# Processing Record 45 of Set 5 | skovorodino
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=skovorodino&units=imperial
# 53.9833
# 2023-07-27
# Processing Record 46 of Set 5 | bouna
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=bouna&units=imperial
# 9.2667
# 2023-07-27
# Processing Record 47 of Set 5 | onguday
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=onguday&units=imperial
# 50.75
# 2023-07-27
# Processing Record 48 of Set 5 | horta
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=horta&units=imperial
# 38.5333
# 2023-07-27
# Processing Record 49 of Set 5 | burutu
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=burutu&units=imperial
# 5.3509
# 2023-07-27
# Processing Record 0 of Set 6 | craig
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=craig&units=imperial
# 40.5153
# 2023-07-27
# Processing Record 1 of Set 6 | metlili chaamba
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=metlili chaamba&units=imperial
# 32.2667
# 2023-07-27
# Processing Record 2 of Set 6 | riohacha
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=riohacha&units=imperial
# 11.5444
# 2023-07-27
# Processing Record 3 of Set 6 | bahua
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=bahua&units=imperial
# 25.85
# 2023-07-27
# Processing Record 4 of Set 6 | kataragama
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=kataragama&units=imperial
# City not found. Skipping...
# Processing Record 5 of Set 6 | hamada
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=hamada&units=imperial
# 34.8833
# 2023-07-27
# Processing Record 6 of Set 6 | miyanoura
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=miyanoura&units=imperial
# City not found. Skipping...
# Processing Record 7 of Set 6 | hihifo
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=hihifo&units=imperial
# City not found. Skipping...
# Processing Record 8 of Set 6 | shchuchinsk
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=shchuchinsk&units=imperial
# 52.9333
# 2023-07-27
# Processing Record 9 of Set 6 | astrea
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=astrea&units=imperial
# 9.4983
# 2023-07-27
# Processing Record 10 of Set 6 | east london
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=east london&units=imperial
# -33.0153
# 2023-07-27
# Processing Record 11 of Set 6 | vernon
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=vernon&units=imperial
# 50.2581
# 2023-07-27
# Processing Record 12 of Set 6 | yarkovo
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=yarkovo&units=imperial
# 57.4028
# 2023-07-27
# Processing Record 13 of Set 6 | wanlaweyn
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=wanlaweyn&units=imperial
# 2.6185
# 2023-07-27
# Processing Record 14 of Set 6 | coxen hole
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=coxen hole&units=imperial
# 16.3244
# 2023-07-27
# Processing Record 15 of Set 6 | akrehamn
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=akrehamn&units=imperial
# 59.2667
# 2023-07-27
# Processing Record 16 of Set 6 | likasi
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=likasi&units=imperial
# -10.9814
# 2023-07-27
# Processing Record 17 of Set 6 | sampit
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=sampit&units=imperial
# -2.5333
# 2023-07-27
# Processing Record 18 of Set 6 | luanda
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=luanda&units=imperial
# -8.8368
# 2023-07-27
# Processing Record 19 of Set 6 | west bay
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=west bay&units=imperial
# 19.3667
# 2023-07-27
# Processing Record 20 of Set 6 | yaren
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=yaren&units=imperial
# -0.5472
# 2023-07-27
# Processing Record 21 of Set 6 | pisco
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=pisco&units=imperial
# -13.7
# 2023-07-27
# Processing Record 22 of Set 6 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=ixtapa&units=imperial
# 20.7
# 2023-07-27
# Processing Record 23 of Set 6 | margaret river
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=margaret river&units=imperial
# -33.95
# 2023-07-27
# Processing Record 24 of Set 6 | toga village
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=toga village&units=imperial
# City not found. Skipping...
# Processing Record 25 of Set 6 | egilsstadir
# ...
# 40.8108
# 2023-07-27
# Processing Record 40 of Set 10 | temax
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=temax&units=imperial
# 21.15
# 2023-07-27
# Processing Record 41 of Set 10 | benghazi
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=benghazi&units=imperial
# 32.1167
# 2023-07-27
# Processing Record 42 of Set 10 | magnitogorsk
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=magnitogorsk&units=imperial
# 53.4186
# 2023-07-27
# Processing Record 43 of Set 10 | hadibu
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=hadibu&units=imperial
# 12.65
# 2023-07-27
# Processing Record 44 of Set 10 | yanagawa
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=yanagawa&units=imperial
# 33.1667
# 2023-07-27
# Processing Record 45 of Set 10 | fonadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=fonadhoo&units=imperial
# City not found. Skipping...
# Processing Record 46 of Set 10 | carai
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=carai&units=imperial
# -17.1889
# 2023-07-27
# Processing Record 47 of Set 10 | berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=berdigestyakh&units=imperial
# 62.0989
# 2023-07-27
# Processing Record 48 of Set 10 | villa huidobro
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=villa huidobro&units=imperial
# -34.8383
# 2023-07-27
# Processing Record 49 of Set 10 | aras-asan
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=aras-asan&units=imperial
# 8.8908
# 2023-07-27
# Processing Record 0 of Set 11 | amontada
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=amontada&units=imperial
# -3.3617
# 2023-07-27
# Processing Record 1 of Set 11 | gerash
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=gerash&units=imperial
# 27.6652
# 2023-07-27
# Processing Record 2 of Set 11 | erenhot
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=erenhot&units=imperial
# 43.6475
# 2023-07-27
# Processing Record 3 of Set 11 | zhaotong
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=zhaotong&units=imperial
# 27.3167
# 2023-07-27
# Processing Record 4 of Set 11 | nuuk
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=nuuk&units=imperial
# 64.1835
# 2023-07-27
# Processing Record 5 of Set 11 | lycksele
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=lycksele&units=imperial
# 64.5954
# 2023-07-27
# Processing Record 6 of Set 11 | cable beach
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=cable beach&units=imperial
# City not found. Skipping...
# Processing Record 7 of Set 11 | juan griego
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=juan griego&units=imperial
# 11.0817
# 2023-07-27
# Processing Record 8 of Set 11 | oyama
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=oyama&units=imperial
# 36.3
# 2023-07-27
# Processing Record 9 of Set 11 | nola
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=nola&units=imperial
# 40.922
# 2023-07-27
# Processing Record 10 of Set 11 | tidjikja
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=tidjikja&units=imperial
# 18.5564
# 2023-07-27
# Processing Record 11 of Set 11 | ifakara
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=ifakara&units=imperial
# -8.1333
# 2023-07-27
# Processing Record 12 of Set 11 | tobi village
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=tobi village&units=imperial
# City not found. Skipping...
# Processing Record 13 of Set 11 | katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=katsuura&units=imperial
# 35.1333
# 2023-07-27
# Processing Record 14 of Set 11 | hammond
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=hammond&units=imperial
# 41.5834
# 2023-07-27
# Processing Record 15 of Set 11 | ambovombe
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=ambovombe&units=imperial
# -25.1667
# 2023-07-27
# Processing Record 16 of Set 11 | bodo
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=bodo&units=imperial
# 67.28
# 2023-07-27
# Processing Record 17 of Set 11 | cherdyn'
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=cherdyn'&units=imperial
# 60.403
# 2023-07-27
# Processing Record 18 of Set 11 | sumbe
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=sumbe&units=imperial
# -11.2061
# 2023-07-27
# Processing Record 19 of Set 11 | broken hill
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=broken hill&units=imperial
# -31.95
# 2023-07-27
# Processing Record 20 of Set 11 | darab
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=darab&units=imperial
# 28.7519
# 2023-07-27
# Processing Record 21 of Set 11 | yeppoon
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=yeppoon&units=imperial
# -23.1333
# 2023-07-27
# Processing Record 22 of Set 11 | petrolina
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=petrolina&units=imperial
# -9.3986
# 2023-07-27
# Processing Record 23 of Set 11 | mariental
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=mariental&units=imperial
# -24.6333
# 2023-07-27
# Processing Record 24 of Set 11 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=cockburn town&units=imperial
# 21.4612
# 2023-07-27
# Processing Record 25 of Set 11 | taroa
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=taroa&units=imperial
# 8.7058
# 2023-07-27
# Processing Record 26 of Set 11 | saynshand
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=saynshand&units=imperial
# 44.8824
# 2023-07-27
# Processing Record 27 of Set 11 | fumel
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=fumel&units=imperial
# 44.4986
# 2023-07-27
# Processing Record 28 of Set 11 | vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=vila velha&units=imperial
# -20.3297
# 2023-07-27
# Processing Record 29 of Set 11 | guatire
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=guatire&units=imperial
# 10.4762
# 2023-07-27
# Processing Record 30 of Set 11 | masterton
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=masterton&units=imperial
# -40.9597
# 2023-07-27
# Processing Record 31 of Set 11 | peniche
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=peniche&units=imperial
# 39.3558
# 2023-07-27
# Processing Record 32 of Set 11 | tangzhai
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=tangzhai&units=imperial
# 34.4328
# 2023-07-27
# Processing Record 33 of Set 11 | barth
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=barth&units=imperial
# 54.3635
# 2023-07-27
# Processing Record 34 of Set 11 | kerikeri
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=kerikeri&units=imperial
# -35.2268
# 2023-07-27
# Processing Record 35 of Set 11 | rikaze
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=rikaze&units=imperial
# 29.25
# 2023-07-27
# Processing Record 36 of Set 11 | zaozersk
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=zaozersk&units=imperial
# 69.4005
# 2023-07-27
# Processing Record 37 of Set 11 | uravakonda
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=uravakonda&units=imperial
# 14.95
# 2023-07-27
# Processing Record 38 of Set 11 | kiruna
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=kiruna&units=imperial
# 67.8557
# 2023-07-27
# Processing Record 39 of Set 11 | ratnagiri
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=ratnagiri&units=imperial
# 16.9833
# 2023-07-27
# Processing Record 40 of Set 11 | bac lieu
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=bac lieu&units=imperial
# 9.285
# 2023-07-27
# Processing Record 41 of Set 11 | severo-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=severo-yeniseyskiy&units=imperial
# 60.3725
# 2023-07-27
# Processing Record 42 of Set 11 | south cleveland
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=south cleveland&units=imperial
# 35.1412
# 2023-07-27
# Processing Record 43 of Set 11 | tangalle
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=tangalle&units=imperial
# 6.024
# 2023-07-27
# Processing Record 44 of Set 11 | oguta
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=oguta&units=imperial
# 5.7089
# 2023-07-27
# Processing Record 45 of Set 11 | menongue
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=menongue&units=imperial
# -14.6585
# 2023-07-27
# Processing Record 46 of Set 11 | galliano
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=galliano&units=imperial
# 29.4422
# 2023-07-27
# Processing Record 47 of Set 11 | zhanaozen
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=zhanaozen&units=imperial
# 43.3
# 2023-07-27
# Processing Record 48 of Set 11 | magong
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=magong&units=imperial
# 23.5654
# 2023-07-27
# Processing Record 49 of Set 11 | da nang
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=da nang&units=imperial
# 16.0678
# 2023-07-27
# Processing Record 0 of Set 12 | virrat
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=virrat&units=imperial
# 62.2476
# 2023-07-27
# Processing Record 1 of Set 12 | aripuana
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=aripuana&units=imperial
# -9.1667
# 2023-07-27
# Processing Record 2 of Set 12 | bikenibeu village
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=bikenibeu village&units=imperial
# 1.3673
# 2023-07-27
# Processing Record 3 of Set 12 | xai-xai
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=xai-xai&units=imperial
# -25.0519
# 2023-07-27
# Processing Record 4 of Set 12 | mount pleasant
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=mount pleasant&units=imperial
# 32.7941
# 2023-07-27
# Processing Record 5 of Set 12 | mont-dore
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=mont-dore&units=imperial
# -22.2833
# 2023-07-27
# Processing Record 6 of Set 12 | balabac
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=balabac&units=imperial
# 7.9868
# 2023-07-27
# Processing Record 7 of Set 12 | sainyabuli
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=sainyabuli&units=imperial
# 19.25
# 2023-07-27
# Processing Record 8 of Set 12 | cocachacra
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=cocachacra&units=imperial
# -17.0883
# 2023-07-27
# Processing Record 9 of Set 12 | tannum sands
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=tannum sands&units=imperial
# -23.9504
# 2023-07-27
# Processing Record 10 of Set 12 | la mira
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=la mira&units=imperial
# 18.035
# 2023-07-27
# Processing Record 11 of Set 12 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=oranjemund&units=imperial
# -28.55
# 2023-07-27
# Processing Record 12 of Set 12 | shimoda
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=shimoda&units=imperial
# 34.6667
# 2023-07-27
# Processing Record 13 of Set 12 | flying fish cove
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=flying fish cove&units=imperial
# -10.4217
# 2023-07-27
# Processing Record 14 of Set 12 | changli
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=changli&units=imperial
# 39.7042
# 2023-07-27
# Processing Record 15 of Set 12 | makushino
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=makushino&units=imperial
# 55.2103
# 2023-07-27
# Processing Record 16 of Set 12 | baiao
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=baiao&units=imperial
# -2.7906
# 2023-07-27
# Processing Record 17 of Set 12 | linares
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=linares&units=imperial
# -35.85
# 2023-07-27
# Processing Record 18 of Set 12 | bethanie
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=bethanie&units=imperial
# -26.4833
# 2023-07-27
# Processing Record 19 of Set 12 | puerto quijarro
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=puerto quijarro&units=imperial
# -17.7833
# 2023-07-27
# Processing Record 20 of Set 12 | tromso
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=tromso&units=imperial
# 69.6496
# 2023-07-27
# Processing Record 21 of Set 12 | toliara
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=toliara&units=imperial
# -23.35
# 2023-07-27
# Processing Record 22 of Set 12 | coahuayana de hidalgo
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=coahuayana de hidalgo&units=imperial
# 18.7
# 2023-07-27
# Processing Record 23 of Set 12 | alotau
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=alotau&units=imperial
# City not found. Skipping...
# Processing Record 24 of Set 12 | fortaleza
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=fortaleza&units=imperial
# -3.7227
# 2023-07-27
# Processing Record 25 of Set 12 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=thinadhoo&units=imperial
# 0.5333
# 2023-07-27
# Processing Record 26 of Set 12 | setti fatma
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=setti fatma&units=imperial
# City not found. Skipping...
# Processing Record 27 of Set 12 | bastos
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=bastos&units=imperial
# -21.9219
# 2023-07-27
# Processing Record 28 of Set 12 | korla
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=korla&units=imperial
# 41.7597
# 2023-07-27
# Processing Record 29 of Set 12 | marsaskala
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=marsaskala&units=imperial
# City not found. Skipping...
# Processing Record 30 of Set 12 | kone
# http://api.openweathermap.org/data/2.5/weather?appid=8d8264dbbcc687c68b6332c2c48a6117&q=kone&units=imperial
# -21.0595
# 2023-07-27
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          555
# Lat           555
# Lng           555
# Max Temp      555
# Humidity      555
# Cloudiness    555
# Wind Speed    555
# Country       555
# Date          555
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  invercargill -46.4000  168.3500     45.05        78         100
# 1     adamstown -25.0660 -130.1015     67.39        61          29
# 2       setubal  38.5244   -8.8882     65.17        90           6
# 3         mejit  10.2753  170.8646     82.63        80         100
# 4    beitbridge -22.2167   30.0000     55.83        70           6
#
#    Wind Speed Country        Date
# 0       14.83      NZ  2023-07-27
# 1       12.01      PN  2023-07-27
# 2       10.33      PT  2023-07-27
# 3       16.35      MH  2023-07-27
# 4        3.51      ZW  2023-07-27

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        invercargill -46.4000  168.3500     45.05        78         100
# 1           adamstown -25.0660 -130.1015     67.39        61          29
# 2             setubal  38.5244   -8.8882     65.17        90           6
# 3               mejit  10.2753  170.8646     82.63        80         100
# 4          beitbridge -22.2167   30.0000     55.83        70           6
#
#          Wind Speed Country        Date
# City_ID
# 0             14.83      NZ  2023-07-27
# 1             12.01      PN  2023-07-27
# 2             10.33      PT  2023-07-27
# 3             16.35      MH  2023-07-27
# 4              3.51      ZW  2023-07-27

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

#capomulin_data=clean_df.loc[clean_df["Drug Regimen"]=="Capomulin"]
#avg_vol_cap=capomulin_data.groupby(capomulin_data["Mouse ID"]).mean(numeric_only=True)
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"])
# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("Latitude vs. Temperature")
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Latitude vs. Humidity")
# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%))")
plt.title("Latitude vs. Cloudiness")
# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s))")
plt.title("Latitude vs. Wind Speed")
# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def regression_func(x_values,y_values):
    rvalue =float(0.0)
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    return regress_values, line_eq, rvalue

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hem = pd.DataFrame(city_data_df.loc[city_data_df['Lat']>=0,:])


# Display sample data
northern_hem.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2           setubal  38.5244   -8.8882     65.17        90           6
# 3             mejit  10.2753  170.8646     82.63        80         100
# 6          bilibino  68.0546  166.4372     52.43        69         100
# 7        georgetown   5.4112  100.3354     86.02        83          20
# 9            macapa   0.0389  -51.0664     76.98       100          75
#
#          Wind Speed Country        Date
# City_ID
# 2             10.33      PT  2023-07-27
# 3             16.35      MH  2023-07-27
# 6              3.60      RU  2023-07-27
# 7              3.44      MY  2023-07-27
# 9              3.44      BR  2023-07-27

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hem = pd.DataFrame(city_data_df.loc[city_data_df['Lat']<0,:])

# Display sample data
southern_hem.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          invercargill -46.4000  168.3500     45.05        78         100
# 1             adamstown -25.0660 -130.1015     67.39        61          29
# 4            beitbridge -22.2167   30.0000     55.83        70           6
# 5        puerto natales -51.7236  -72.4875     28.69        93         100
# 8          port lincoln -34.7333  135.8667     66.06        57          96
#
#          Wind Speed Country        Date
# City_ID
# 0             14.83      NZ  2023-07-27
# 1             12.01      PN  2023-07-27
# 4              3.51      ZW  2023-07-27
# 5              2.51      CL  2023-07-27
# 8             20.47      AU  2023-07-27

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hem['Lat']
y_values = northern_hem['Max Temp']
regress_values, line_eq, rval = regression_func(x_values,y_values)
print(f"The r-squared is: {rval**2}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (f)')
plt.show()
# Out:
# The r-squared is: 0.3348554336550262

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hem['Lat']
y_values = southern_hem['Max Temp']
regress_values, line_eq, rval= regression_func(x_values,y_values)
print(f"The r-squared is: {rval**2}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,80),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (f)')
plt.show()
# Out:
# The r-squared is: 0.61857349505053

# %% [markdown]
# **Discussion about the linear relationship:** Based on the R values there is most likely a relationship between Latitude and temperature
# The max temp in the southern hemisphere decreases at a rate of .9 for every degree of
# latitude we move away from 0. Respcitvely the max temp in the northen hemisphere decreases a rate of aprox .4 for every degree of latitude
# we move away from the equator. The linear relationship will change depending on the random city dataset however after multiple runs,
# the relationship seems to be very consitent with a average city count of 589 in the data set after try/except exclusions.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hem['Lat']
y_values = northern_hem['Humidity']
regress_values,line_eq,rval = regression_func(x_values,y_values)
print(f"The r-squared is: {rval**2}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()
# Out:
# The r-squared is: 0.003834421757085033

# %%
# Southern Hemisphere
x_values = southern_hem['Lat']
y_values = southern_hem['Humidity']
regress_values, line_eq, ravl= regression_func(x_values,y_values)
print(f"The r-squared is: {rval**2}")

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()
# Out:
# The r-squared is: 0.003834421757085033

# %% [markdown]
# **Discussion about the linear relationship:** Based on the R values the linear regression model does not seem to fit this dataset. There does not seem to be a relationship betewen a linear relationship between humidity and latitude.
# The R value is very close to 0. I would theorize that there would be more of a linear relationship between longitude and humidty if we are looking at the east or west side of a specific continent as humidity would increase the closer we get to the coast.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hem['Lat']
y_values = northern_hem['Cloudiness']
regress_values, line_eq, rval= regression_func(x_values,y_values)
print(f"The r-squared is: {rval**2}")
x = np.linspace(0, 10, 100)
y = 4 + 2 * np.sin(2 * x)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.show()
# Out:
# The r-squared is: 0.0039946777853295526

# %%
# Southern Hemisphere
x_values = southern_hem['Lat']
y_values = southern_hem['Cloudiness']
regress_values, line_eq, rval= regression_func(x_values,y_values)
print(f"The r-squared is: {rval**2}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.show()
# Out:
# The r-squared is: 0.03491318276614976

# %% [markdown]
# **Discussion about the linear relationship:** Based on the R values linear regression model does not seem to be a good method to explain this dataset.
# The R value is very close to 0. I think a logistic regression would fit this data set better.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hem['Lat']
y_values = northern_hem['Wind Speed']
regress_values, line_eq, rval= regression_func(x_values,y_values)
print(f"The r-squared is: {rval**2}")

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,22),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()
# Out:
# The r-squared is: 0.027434019516027756

# %%
# Southern Hemisphere
x_values = southern_hem['Lat']
y_values = southern_hem['Wind Speed']
regress_values, line_eq, rval= regression_func(x_values,y_values)
print(f"The r-squared is: {rval**2}")

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()
# Out:
# The r-squared is: 0.02186921078189333

# %% [markdown]
# **Discussion about the linear relationship:** Similar to the previous results i don't think there is a correlation here between wind speed and latitude.
